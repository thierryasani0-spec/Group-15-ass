# %%
# !pip install folium haversine
# Out:
# Collecting folium
#   Downloading folium-0.20.0-py2.py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: haversine in c:\users\anin\.anaconda\lib\site-packages (2.9.0)
# Collecting branca>=0.6.0 (from folium)
#   Downloading branca-0.8.2-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: jinja2>=2.9 in c:\users\anin\.anaconda\lib\site-packages (from folium) (3.1.6)
# Requirement already satisfied: numpy in c:\users\anin\.anaconda\lib\site-packages (from folium) (2.3.5)
# Requirement already satisfied: requests in c:\users\anin\.anaconda\lib\site-packages (from folium) (2.32.5)
# Requirement already satisfied: xyzservices in c:\users\anin\.anaconda\lib\site-packages (from folium) (2025.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\anin\.anaconda\lib\site-packages (from jinja2>=2.9->folium) (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\anin\.anaconda\lib\site-packages (from requests->folium) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\anin\.anaconda\lib\site-packages (from requests->folium) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\anin\.anaconda\lib\site-packages (from requests->folium) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\anin\.anaconda\lib\site-packages (from requests->folium) (2025.11.12)
# Downloading folium-0.20.0-py2.py3-none-any.whl (113 kB)
# Downloading branca-0.8.2-py3-none-any.whl (26 kB)
# Installing collected packages: branca, folium
#
#    ---------------------------------------- 0/2 [branca]
#    -------------------- ------------------- 1/2 [folium]
#    -------------------- ------------------- 1/2 [folium]
#    -------------------- ------------------- 1/2 [folium]
#    -------------------- ------------------- 1/2 [folium]
#    -------------------- ------------------- 1/2 [folium]
#    -------------------- ------------------- 1/2 [folium]
#    -------------------- ------------------- 1/2 [folium]
#    -------------------- ------------------- 1/2 [folium]
#    -------------------- ------------------- 1/2 [folium]
#    ---------------------------------------- 2/2 [folium]
#
# Successfully installed branca-0.8.2 folium-0.20.0

# %%
import csv
import folium
from haversine import haversine, Unit
from collections import OrderedDict

# %%
def read_places_from_csv(csv_file):
    places = OrderedDict()

    with open(csv_file, newline="", encoding="utf-8") as file:
        reader = csv.DictReader(file)
        for row in reader:
            name = row["Location"].strip()
            lat = float(row["Latitude"])
            lon = float(row["Longitude"])
            places[name] = (lat, lon)

    return places

# %%
csv_path = r"c:/Users/Anin/Desktop/map.csv"
places = read_places_from_csv(csv_path)

print("ORDERED LOCATIONS:")
for p in places:
    print(p)
# Out:
# ORDERED LOCATIONS:
# st.luke hospital
# provision shop
# T junction 1
# Omega fire ministry
# Convenant university junction
# Tilled cite 1
# Baron hotel entrance
# Mustardseed shop
# Da costa residence
# T junction 2
# Gas shop
# T junction 3
# Big dora shop
# Faith balingual
# skovedemalma cite
# Guest house 1
# Snooker/barber shop
# HIPS university
# Nyla's affordable boutique
# Alfredo's fashion shop
# St.Luke junction
# Saw mill 1
# Remi's world wide entrance
# Saw mill 2
# Shanty's food
# Hotel Yanze entrance
# St.Louis feed mill
# Djos gracias building
# Cathedral
# Blue empire holding
# SUBUTECH entrance
# Tatabong lounge
# Alino's metal
# New taste restaurant
# Molyko omnisport staduim
# HIBMAT campus B junction
# Stone cite
# Emma city building
# CBC church
# Saw mill 3
# LUKMEF building
# NADEV head office
# HIBMAT campus B entrance
# HIBMAT campus B

# %%
def build_distance_graph(places, unit="km"):
    graph = OrderedDict()
    keys = list(places.keys())

    for i in range(len(keys) - 1):
        start = keys[i]
        end = keys[i + 1]

        km = haversine(
            places[start],
            places[end],
            unit=Unit.KILOMETERS
        )

        distance = km if unit == "km" else km * 100_000

        graph[start] = {
            "to": end,
            "distance": distance,
            "unit": unit
        }

    return graph

# %%
graph_km = build_distance_graph(places, unit="km")
graph_cm = build_distance_graph(places, unit="cm")

# %%
print("DISTANCES IN KM:")
for start, info in graph_km.items():
    print(f"{start} → {info['to']} = {info['distance']:.4f} km")

print("\nDISTANCES IN CM:")
for start, info in graph_cm.items():
    print(f"{start} → {info['to']} = {info['distance']:.2f} cm")
# Out:
# DISTANCES IN KM:
# st.luke hospital → provision shop = 0.0640 km
# provision shop → T junction 1 = 0.0310 km
# T junction 1 → Omega fire ministry = 0.0310 km
# Omega fire ministry → Convenant university junction = 0.0252 km
# Convenant university junction → Tilled cite 1 = 0.0223 km
# Tilled cite 1 → Baron hotel entrance = 0.0265 km
# Baron hotel entrance → Mustardseed shop = 0.0359 km
# Mustardseed shop → Da costa residence = 0.0380 km
# Da costa residence → T junction 2 = 0.0417 km
# T junction 2 → Gas shop = 0.0128 km
# Gas shop → T junction 3 = 0.0268 km
# T junction 3 → Big dora shop = 0.0324 km
# Big dora shop → Faith balingual = 0.0219 km
# Faith balingual → skovedemalma cite = 0.0385 km
# skovedemalma cite → Guest house 1 = 0.0448 km
# Guest house 1 → Snooker/barber shop = 0.1341 km
# Snooker/barber shop → HIPS university = 0.0541 km
# HIPS university → Nyla's affordable boutique = 0.0458 km
# Nyla's affordable boutique → Alfredo's fashion shop = 0.0161 km
# Alfredo's fashion shop → St.Luke junction = 0.0407 km
# St.Luke junction → Saw mill 1 = 0.0394 km
# Saw mill 1 → Remi's world wide entrance = 0.0317 km
# Remi's world wide entrance → Saw mill 2 = 0.0276 km
# Saw mill 2 → Shanty's food = 0.0152 km
# Shanty's food → Hotel Yanze entrance = 0.0204 km
# Hotel Yanze entrance → St.Louis feed mill = 0.0307 km
# St.Louis feed mill → Djos gracias building = 0.0394 km
# Djos gracias building → Cathedral = 0.0349 km
# Cathedral → Blue empire holding = 0.0727 km
# Blue empire holding → SUBUTECH entrance = 0.0623 km
# SUBUTECH entrance → Tatabong lounge = 0.0571 km
# Tatabong lounge → Alino's metal = 0.0706 km
# Alino's metal → New taste restaurant = 0.0457 km
# New taste restaurant → Molyko omnisport staduim = 0.0495 km
# Molyko omnisport staduim → HIBMAT campus B junction = 0.0225 km
# HIBMAT campus B junction → Stone cite = 0.0811 km
# Stone cite → Emma city building = 0.0252 km
# Emma city building → CBC church = 0.0346 km
# CBC church → Saw mill 3 = 0.0161 km
# Saw mill 3 → LUKMEF building = 0.0577 km
# LUKMEF building → NADEV head office = 0.0344 km
# NADEV head office → HIBMAT campus B entrance = 0.1090 km
# HIBMAT campus B entrance → HIBMAT campus B = 0.1377 km
#
# DISTANCES IN CM:
# st.luke hospital → provision shop = 6397.76 cm
# provision shop → T junction 1 = 3104.55 cm
# T junction 1 → Omega fire ministry = 3095.53 cm
# Omega fire ministry → Convenant university junction = 2516.22 cm
# Convenant university junction → Tilled cite 1 = 2227.64 cm
# Tilled cite 1 → Baron hotel entrance = 2652.85 cm
# Baron hotel entrance → Mustardseed shop = 3585.12 cm
# Mustardseed shop → Da costa residence = 3802.25 cm
# Da costa residence → T junction 2 = 4165.45 cm
# T junction 2 → Gas shop = 1278.74 cm
# Gas shop → T junction 3 = 2684.02 cm
# T junction 3 → Big dora shop = 3239.49 cm
# Big dora shop → Faith balingual = 2191.11 cm
# Faith balingual → skovedemalma cite = 3848.29 cm
# skovedemalma cite → Guest house 1 = 4476.87 cm
# Guest house 1 → Snooker/barber shop = 13412.08 cm
# Snooker/barber shop → HIPS university = 5412.12 cm
# HIPS university → Nyla's affordable boutique = 4578.70 cm
# Nyla's affordable boutique → Alfredo's fashion shop = 1614.06 cm
# Alfredo's fashion shop → St.Luke junction = 4074.91 cm
# St.Luke junction → Saw mill 1 = 3939.55 cm
# Saw mill 1 → Remi's world wide entrance = 3166.77 cm
# Remi's world wide entrance → Saw mill 2 = 2755.72 cm
# Saw mill 2 → Shanty's food = 1523.68 cm
# Shanty's food → Hotel Yanze entrance = 2035.63 cm
# Hotel Yanze entrance → St.Louis feed mill = 3065.98 cm
# St.Louis feed mill → Djos gracias building = 3942.83 cm
# Djos gracias building → Cathedral = 3493.14 cm
# Cathedral → Blue empire holding = 7265.49 cm
# Blue empire holding → SUBUTECH entrance = 6225.96 cm
# SUBUTECH entrance → Tatabong lounge = 5706.43 cm
# Tatabong lounge → Alino's metal = 7060.83 cm
# Alino's metal → New taste restaurant = 4568.34 cm
# New taste restaurant → Molyko omnisport staduim = 4948.24 cm
# Molyko omnisport staduim → HIBMAT campus B junction = 2252.60 cm
# HIBMAT campus B junction → Stone cite = 8106.17 cm
# Stone cite → Emma city building = 2521.59 cm
# Emma city building → CBC church = 3459.92 cm
# CBC church → Saw mill 3 = 1613.60 cm
# Saw mill 3 → LUKMEF building = 5772.23 cm
# LUKMEF building → NADEV head office = 3437.35 cm
# NADEV head office → HIBMAT campus B entrance = 10896.02 cm
# HIBMAT campus B entrance → HIBMAT campus B = 13772.69 cm

# %%
def total_distance(graph):
    return sum(info["distance"] for info in graph.values())

print("\nTOTAL DISTANCE:")
print(f"{total_distance(graph_km):.4f} km")
print(f"{total_distance(graph_cm):.2f} cm")
# Out:
# TOTAL DISTANCE:
# 1.8989 km
# 189888.51 cm

# %%
start_coords = list(places.values())[0]
m = folium.Map(location=start_coords, zoom_start=16)

# %%
for name, coords in places.items():
    folium.Marker(
        location=coords,
        popup=name,
        icon=folium.Icon(color="blue")
    ).add_to(m)

# %%
folium.PolyLine(
    locations=list(places.values()),
    color="red",
    weight=4,
    tooltip=f"Total Distance: {total_distance(graph_km):.3f} km"
).add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_798334c0489c730260843ca9b2cfa7ce {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_798334c0489c730260843ca9b2cfa7ce&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_798334c0489c730260843ca9b2cfa7ce = L.map(
#                 &quot;map_798334c0489c730260843ca9b2cfa7ce&quot;,
#                 {
#                     center: [4.164948, 9.273951],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 16,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0192303a8d7f9d953b7527d1077dbdf6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0192303a8d7f9d953b7527d1077dbdf6.addTo(map_798334c0489c730260843ca9b2cfa7ce);
#
#
#             var marker_cf8c1cae039e67dcc33e5e1b00eab245 = L.marker(
#                 [4.164948, 9.273951],
#                 {
# }
#             ).addTo(map_798334c0489c730260843ca9b2cfa7ce);
#
#
#             var icon_e0042ec8c0ff14e58db2e2563fd9eece = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_f791b0959fb4e1d932150b9a668d8e72 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_45594a3f5eb55fd03fb06ccd1691f9ad = $(`&lt;div id=&quot;html_45594a3f5eb55fd03fb06ccd1691f9ad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;st.luke hospital&lt;/div&gt;`)[0];
#                 popup_f791b0959fb4e1d932150b9a668d8e72.setContent(html_45594a3f5eb55fd03fb06ccd1691f9ad);
#
#
#
#         marker_cf8c1cae039e67dcc33e5e1b00eab245.bindPopup(popup_f791b0959fb4e1d932150b9a668d8e72)
#         ;
#
#
#
#
#                 marker_cf8c1cae039e67dcc33e5e1b00eab245.setIcon(icon_e0042ec8c0ff14e58db2e2563fd9eece);
#
#
#             var marker_450affb08622a0e46b6a18156d025531 = L.marker(
#                 [4.165516, 9.274043],
#                 {
# }
#             ).addTo(map_798334c0489c730260843ca9b2cfa7ce);
#
#
#             var icon_a02769ebe14115b61f95baddc8197073 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_7190b50ee1e525362d7a40199256c359 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8071ef2aaa8cdf7d66fd08a385ccd196 = $(`&lt;div id=&quot;html_8071ef2aaa8cdf7d66fd08a385ccd196&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;provision shop&lt;/div&gt;`)[0];
#                 popup_7190b50ee1e525362d7a40199256c359.setContent(html_8071ef2aaa8cdf7d66fd08a385ccd196);
#
#
#
#         marker_450affb08622a0e46b6a18156d025531.bindPopup(popup_7190b50ee1e525362d7a40199256c359)
#         ;
#
#
#
#
#                 marker_450affb08622a0e46b6a18156d025531.setIcon(icon_a02769ebe14115b61f95baddc8197073);
#
#
#             var marker_aff40a1635c4a4ec633028a4d88f24a2 = L.marker(
#                 [4.165603, 9.274309],
#                 {
# }
#             ).addTo(map_798334c0489c730260843ca9b2cfa7ce);
#
#
#             var icon_b8bb38bea4387952d5a5432486e80928 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_6eb070e8a84dc2ce05bca8b2c26a20e8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_01c289977543e22423402953ceb6748b = $(`&lt;div id=&quot;html_01c289977543e22423402953ceb6748b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;T junction 1&lt;/div&gt;`)[0];
#                 popup_6eb070e8a84dc2ce05bca8b2c26a20e8.setContent(html_01c289977543e22423402953ceb6748b);
#
#
#
#         marker_aff40a1635c4a4ec633028a4d88f24a2.bindPopup(popup_6eb070e8a84dc2ce05bca8b2c26a20e8)
#         ;
#
#
#
#
#                 marker_aff40a1635c4a4ec633028a4d88f24a2.setIcon(icon_b8bb38bea4387952d5a5432486e80928);
#
#
#             var marker_eb421ffc3e1380f683cf74f91a
